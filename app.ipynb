# %% [markdown]
# # Rag for audio and video data

# %%
# %pip install --quiet langchain-text-splitters langchain-community langgraph 
# %pip install -q "langchain[google-genai]"
# %pip install -q langchain langchain-google-genai google-generativeai
# %pip install -qU langchain-qdrant
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Langsmith api key setup

from dotenv import load_dotenv
import os

load_dotenv()

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API")

# %%
# Embedding model and setup

import os

if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = os.getenv("GEMINI_API")

from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
# Google api key setup

import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# Securely input and set API key
if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = os.getenv("GEMINI_API")

# Initialize Gemini 2.0 Flash model
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key=os.environ["GOOGLE_API_KEY"]
)

# Example call
response = llm.invoke([HumanMessage(content="Hello Gemini 2.0!")])
print(response.content)
# Out:
# Hello! It's nice to connect with you. How can I help you today?

# %% [markdown]
# ### Loading the audio data

# %%
# Using whisper model

from faster_whisper import WhisperModel
import os

def transcribe_audio_local(audio_path):
    if not os.path.exists(audio_path):
        raise FileNotFoundError(f"Audio file not found: {audio_path}")
    
    print(f"Loading Whisper model: )")
    model = WhisperModel("small", device="cpu", compute_type="int8")  
    # I have chose this config because it fits best for my machine but you can change as per your machine #configuration. larger the model_size , better the accuracy but it will consume more memory and time. Compute type defines the integer accuracy needed during transcription.
    
    print(f"Transcribing: {audio_path}")
    segments, _ = model.transcribe(audio_path)
    
    text = ""
    for segment in segments:
        # Optional: show timestamps
        print(f"[{segment.start:.2f}s - {segment.end:.2f}s]: {segment.text}")
        text += segment.text + " "
    
    return text.strip()

# %%
transcript = transcribe_audio_local("f1_rules.mp3") 
print(transcript)
# Out:
# 🔍 Loading Whisper model: )
# 🎙️ Transcribing: f1_rules.mp3
# [0.00s - 7.04s]:  An F1 Grand Prix is an absolute festival of excitement and entertainment, taking place
# [7.04s - 12.28s]:  over three to four days with all of the warring action culminating in the race itself.
# [12.28s - 17.04s]:  A traditional Grand Prix weekend starts much sooner than that though, with free free practice
# [17.04s - 21.64s]:  sessions taking place over a couple of days before race day to kick things off.
# [21.64s - 25.84s]:  These sessions give the teams and drivers the chance to learn the track, experiment
# [25.84s - 29.68s]:  with the conditions and test the different setups and configurations they want to use
# [29.68s - 34.16s]:  in qualifying and the race. After those practice sessions are completed, it's
# [34.16s - 39.28s]:  time for qualifying. In essence, this is where all the drivers go out and try to
# [39.28s - 44.92s]:  set the fastest possible lap times they can across three knockout sessions Q1, Q2
# [44.92s - 50.68s]:  and Q3. The fastest driver to survive all knockouts starts the race from the very
# [50.68s - 55.76s]:  front of the grid or pole position. Behind them are the other drivers ordered
# [55.76s - 59.16s]:  from qualifying lap times set in the rest of the starting positions for the
# [59.16s - 63.76s]:  race. The cars use a formation lap to line up in their starting or grid
# [63.76s - 68.12s]:  positions on a start finish straight and wait for the lights to go out and the
# [68.12s - 74.80s]:  race begins. So how is the duration of an F1 race decided? It's a case of simple
# [74.80s - 80.36s]:  maths. A Grand Prix distance is 305 kilometers so divide that by the
# [80.36s - 84.28s]:  length of a single lap and round it up to a whole number and hey presto
# [84.28s - 88.68s]:  that's the number of laps for the race. The only exception is if any
# [88.68s - 93.44s]:  stoppages in the race cause it to run over a two-hour time limit. On the final
# [93.44s - 98.16s]:  lap, the first car to cross the finish line and take the checkered flag wins.
# [98.16s - 102.88s]:  Championship points are awarded for all drivers in the top 10 at the end of
# [102.88s - 108.36s]:  the race with 25 points being awarded for first place, just one single point for
# [108.36s - 113.12s]:  10th place plus a point if they set the fastest lap of the race. Drivers
# [113.12s - 116.88s]:  outside the top 10 don't get any points done even if they set the
# [116.92s - 120.76s]:  fastest lap of the race. This traditional F1 race format is a little
# [120.76s - 124.68s]:  different on sprint race weekends however. Teams only have one practice
# [124.68s - 128.88s]:  session before the competitive weekend starts with sprint qualifying and a
# [128.88s - 134.20s]:  shorter race called the F1 sprint with extra points up for grabs. A sprint
# [134.20s - 137.84s]:  weekend happens a few times per season at predetermined races on the
# [137.84s - 142.92s]:  calendar. In some ways, it's like a regular F1 Grand Prix weekend with
# [142.96s - 147.84s]:  practice sessions to start things off and a Grand Prix race to finish. The key
# [147.84s - 151.72s]:  difference on sprint weekends is with fewer practice sessions it makes way for
# [151.72s - 156.84s]:  two exhilarating high tempo sessions, sprint qualifying and the sprint
# [156.84s - 161.92s]:  itself. A short race held the following day. Sprint qualifying decides the
# [161.92s - 166.12s]:  grid order for Saturday sprint. It's a shorter distance designed to be run
# [166.12s - 172.56s]:  with no mandatory pit stops so more or less flat out racing. Only the top
# [172.60s - 176.96s]:  eight finishes in a sprint get points and fewer of them but these extra
# [176.96s - 181.52s]:  points could prove crucial in a tight championship. You might be
# [181.52s - 185.88s]:  surprised to learn that even getting an F1 race started successfully is not at
# [185.88s - 189.92s]:  all a straightforward process. Loads of moving parts and rolls are all
# [189.92s - 193.80s]:  required to work in complete harmony together to put on the show that is
# [193.80s - 198.48s]:  Formula One racing. Let's look at how it all goes down. The cars are moved
# [198.48s - 202.44s]:  from their garages to the grid around 40 to 50 minutes before the race is
# [202.44s - 205.80s]:  due to start. The drivers know which grid slot they need to place their
# [205.80s - 209.40s]:  cars into to get ready for racing. The qualifying session results decide
# [209.40s - 213.64s]:  that. Mechanics and engineers will keep the cars in the shape they need to be
# [213.64s - 218.64s]:  into race whilst they sit on a grid. An F1 grid is also where some of the
# [218.64s - 223.20s]:  world's biggest celebrities, actors, sports stars, musicians and special
# [223.20s - 227.28s]:  guests can be seen amongst the drivers and cars. Once race start time
# [227.32s - 231.44s]:  is approaching, the teams mechanics and crew return to the garage. The
# [231.44s - 235.96s]:  cars roar into life and we begin what's called the formation. This is a
# [235.96s - 239.80s]:  reduced speed tour around the circuit giving the drivers a chance to
# [239.80s - 245.08s]:  check all systems to examine the conditions and crucially warm up
# [245.08s - 249.04s]:  their tires and brakes before race start. F1 cars work best when
# [249.04s - 252.48s]:  those components are just the right temperature. So the formation lap
# [252.48s - 255.92s]:  preparation by a driver can help towards their race start and
# [255.92s - 259.56s]:  opening laps. This is why you see cars driving on the racing line in
# [259.56s - 263.52s]:  single file on a formation lap, avoiding any dust on the dirtier sides
# [263.52s - 266.72s]:  of the track which drivers don't want on their tires potentially
# [266.72s - 270.12s]:  impacting their race start. Once all cars have returned to their
# [270.12s - 274.20s]:  correct starting positions, if all is well, a green flag is waved at
# [274.20s - 276.68s]:  the back of the grid to communicate to the race start to
# [276.68s - 281.80s]:  that everything and everyone is ready to go. Finally, the grand
# [281.80s - 286.12s]:  stands full quiet. Hearts are firmly in mouths and attention
# [286.12s - 289.72s]:  shifts to the start lights above the start finish line as five
# [289.72s - 295.04s]:  red lights come on one by one. Now you might be wondering why
# [295.04s - 297.92s]:  it's red lights going out rather than a green light to start the
# [297.92s - 301.88s]:  race. When red and green lights were used in the past, the red
# [301.88s - 304.76s]:  lights would go out and then green lights would start the
# [304.76s - 307.72s]:  race a bit like your standard traffic lights for road cars.
# [307.96s - 311.28s]:  But here's a fun fact. Most drivers don't actually look
# [311.28s - 314.00s]:  directly at the lights at race start. They keep them in
# [314.00s - 316.48s]:  their periphery and focus on the track which meant that because
# [316.48s - 319.68s]:  of a minute pause between red lights extinguishing and green
# [319.68s - 322.72s]:  lights coming on, drivers learned that they could react more
# [322.72s - 325.64s]:  quickly to the red lights going off rather than waiting for
# [325.64s - 328.12s]:  the green. As a result of the green lights essentially
# [328.12s - 331.04s]:  becoming redundant, they were removed from the grid start
# [331.04s - 334.32s]:  procedure. But in terms of the race start procedure, as
# [334.32s - 338.16s]:  soon as those lights go out, it's race time. There are
# [338.16s - 341.04s]:  times when a race start needs to be aborted. This could
# [341.04s - 344.08s]:  happen for many different reasons. From a car breaking down
# [344.08s - 346.40s]:  on the grid, to there being a technical issue with
# [346.40s - 349.96s]:  officiating equipment like the lights or timing equipment, or
# [350.04s - 353.68s]:  of course, a drastic change in the weather conditions. If a
# [353.68s - 357.04s]:  start does end up being aborted, the cars slowly lap the
# [357.04s - 360.04s]:  circuit, just like on the formation lap, with no
# [360.04s - 363.56s]:  overtaking allowed. In the event of bad weather or
# [363.56s - 366.60s]:  reduced visibility, there is also the option of the race
# [366.60s - 369.60s]:  starting behind the safety car until it's deemed safe to
# [369.60s - 373.64s]:  race normally. Whether it's pirates or train drivers or
# [373.64s - 376.80s]:  battleships, flags have been used as a form of visual
# [376.80s - 380.20s]:  communication for centuries. So why does something as
# [380.20s - 383.72s]:  technologically advanced as Formula One use this seemingly
# [383.72s - 386.92s]:  archaic system in its racing? It's the quickest,
# [386.92s - 390.48s]:  simplest and easiest form of communication if you need to
# [390.48s - 394.24s]:  get a message to all 20 racing drivers in one go. Think of
# [394.28s - 397.92s]:  motor sports flags as like a very basic language, with
# [397.92s - 400.36s]:  different flags used to communicate key messages to
# [400.36s - 403.64s]:  drivers visually as they travel at super fast speed
# [403.64s - 407.16s]:  around the track. These days it's not just flags. The
# [407.16s - 409.84s]:  same system is supported by track side electronic
# [409.84s - 412.60s]:  boards and driver dash displays on their steering
# [412.60s - 415.44s]:  wheels. This just makes it easier to not miss any
# [415.44s - 417.44s]:  messages and have them being displayed in more
# [417.44s - 421.44s]:  areas of the track. So what do all of the F1 flags
# [421.44s - 424.08s]:  mean? Let's start with one of the more commonly
# [424.08s - 428.48s]:  seen yellow flags. A single yellow flag is waved when
# [428.48s - 430.92s]:  there is an incident in the section of track ahead
# [430.92s - 433.68s]:  and tells the driver to reduce their speed and be
# [433.68s - 437.00s]:  prepared to navigate a hazard ahead. No overtaking is
# [437.00s - 439.96s]:  allowed during any yellow flag conditions and it
# [439.96s - 442.36s]:  must be obvious that drivers have slowed their
# [442.36s - 446.24s]:  speed or they face being penalized. A double
# [446.24s - 448.92s]:  waved yellow flag means that drivers must reduce
# [448.92s - 452.44s]:  their speed significantly or be ready to stop. This
# [452.48s - 454.56s]:  may be because of a blockage on the track ahead
# [454.56s - 458.60s]:  or marshals either on or beside the track. If a
# [458.60s - 460.52s]:  single or double yellow flag is waved during
# [460.52s - 462.84s]:  qualifying drivers should abandon their current
# [462.84s - 465.84s]:  lap and visibly demonstrate they have done so by
# [465.84s - 468.88s]:  slowing down. A slight catch being that as yellow
# [468.88s - 471.56s]:  flags can be section specific that might not
# [471.56s - 474.24s]:  affect every driver trying to put in a fast lap
# [474.24s - 476.44s]:  depending on where in the lap they are when
# [476.44s - 478.88s]:  the flag or flags are waved. Which means
# [478.88s - 481.28s]:  sometimes an element of luck either good or
# [481.28s - 483.68s]:  bad can help or hinder a driver during
# [483.68s - 486.20s]:  quality when a yellow flag is waved. In some
# [486.20s - 489.12s]:  cases during a double yellow flag period the
# [489.12s - 492.16s]:  race director may impose a full course yellow
# [492.16s - 495.72s]:  or fcy. This means that yellow flag rules
# [495.72s - 498.28s]:  apply to the entirety of the track until
# [498.28s - 500.96s]:  further notice. A yellow flag with red
# [500.96s - 503.04s]:  stripes is used to show drivers that the
# [503.04s - 505.16s]:  section of track ahead has suffered a
# [505.16s - 507.76s]:  significant reduction in grip. Due to
# [507.76s - 509.96s]:  something like an oil spillage or excess
# [509.96s - 512.84s]:  water a big drop in grip can have pretty
# [512.84s - 515.68s]:  big consequences at f1 speeds. What
# [515.68s - 517.68s]:  follows a yellow flag once a car is
# [517.68s - 520.00s]:  past the affected area of the track or
# [520.00s - 521.88s]:  when the issue is resolved completely is
# [521.88s - 524.52s]:  a green flag. Green flag equals clear to
# [524.52s - 529.64s]:  go racing. Easy. So go go go! A red flag
# [529.64s - 532.28s]:  means slow down immediately and prepare
# [532.28s - 534.28s]:  to stop while returning slowly and
# [534.28s - 536.16s]:  carefully to the pit lane with no
# [536.16s - 538.52s]:  overtaking permitted. The red flag is
# [538.52s - 540.52s]:  most commonly used in the event the
# [540.52s - 543.04s]:  circuit is deemed temporarily unraceable.
# [543.04s - 545.36s]:  A red flag neutralizes the race,
# [545.36s - 547.52s]:  preserving current race positions while
# [547.52s - 549.20s]:  pausing the action to allow any
# [549.20s - 551.72s]:  problems to be cleared up. Then we have
# [551.72s - 553.32s]:  the blue flag which can be a common
# [553.32s - 555.40s]:  thing to spot during a session. A blue
# [555.40s - 557.04s]:  flag's meaning differs based on the
# [557.04s - 559.08s]:  type of session. During free practice
# [559.08s - 561.40s]:  and qualifying a blue flag indicates to
# [561.40s - 563.12s]:  a driver that faster cars are
# [563.12s - 565.16s]:  approaching behind or when they are
# [565.16s - 566.96s]:  leaving the pit lane. When shown
# [567.04s - 569.20s]:  during a race the blue flag is shown
# [569.20s - 571.16s]:  to a driver or drivers that are
# [571.16s - 573.68s]:  about to be lapped. When shown the
# [573.68s - 575.36s]:  driver must allow the approaching
# [575.36s - 577.36s]:  car or cars to pass at the
# [577.36s - 579.84s]:  earliest opportunity. A black and
# [579.84s - 582.24s]:  white flag is used for unsportsmanlike
# [582.24s - 584.24s]:  behavior, overly aggressive or
# [584.24s - 586.44s]:  unsafe driving but more commonly
# [586.44s - 588.64s]:  applied as an exceeding track limits
# [588.64s - 591.28s]:  warning. This flag tells the driver
# [591.28s - 593.32s]:  there on their final warning before
# [593.32s - 595.76s]:  being given a time penalty. The
# [595.76s - 598.32s]:  rarely seen black flag with an orange
# [598.32s - 600.56s]:  dot or the meatball flag if you're
# [600.56s - 602.16s]:  feeling particularly hungry is a way
# [602.16s - 603.68s]:  of warning a driver that their car
# [603.68s - 605.44s]:  has damage and must return to the
# [605.44s - 607.76s]:  pits for repairs. Much like my
# [607.76s - 609.68s]:  grandmother's bolognese, the meatball
# [609.68s - 611.76s]:  black flag with an orange dot is
# [611.76s - 614.40s]:  final. Once it's shown a driver will
# [614.40s - 616.72s]:  incur severe penalties if they fail
# [616.72s - 619.44s]:  to enter the pit for repairs. A full
# [619.44s - 621.92s]:  completely black flag is something no
# [621.92s - 623.92s]:  driver wants to see. It means the
# [623.92s - 625.60s]:  end of a driver's race and not in a
# [625.60s - 627.44s]:  good way. It means the driver is
# [627.44s - 629.28s]:  disqualified and must return to the
# [629.28s - 631.52s]:  pits immediately. The ultimate
# [631.52s - 633.52s]:  shame. They could be disqualified for
# [633.52s - 635.28s]:  their on-track behavior or a
# [635.28s - 636.80s]:  technical infringement by the team
# [636.80s - 638.40s]:  might have been discovered. Either
# [638.40s - 641.84s]:  way, a black flag is terminal. Then
# [641.84s - 643.52s]:  there is of course the checkered
# [643.52s - 645.84s]:  flag. In practice and qualifying it
# [645.84s - 648.16s]:  means times up. Laptimes are
# [648.16s - 650.24s]:  recorded until drivers see the flag
# [650.24s - 652.16s]:  but once they pass this flag they
# [652.16s - 654.24s]:  must return to the pits. For the
# [654.24s - 655.84s]:  race though the checkered flag
# [655.84s - 658.08s]:  signals glory. It's waved at the
# [658.08s - 659.52s]:  finish line to the driver who
# [659.52s - 661.60s]:  completes the race distance first
# [661.60s - 665.52s]:  and then every driver behind them.
# [665.52s - 667.36s]:  The F1 safety car isn't just
# [667.36s - 668.96s]:  something nice to look at, which
# [668.96s - 670.96s]:  it most definitely is. It's an
# [670.96s - 672.40s]:  essential part of hosting a
# [672.40s - 674.48s]:  successful and safe event. The
# [674.48s - 676.00s]:  race director decides when to
# [676.00s - 677.68s]:  deploy the safety car and it's
# [677.68s - 679.36s]:  generally used when an incident is
# [679.36s - 681.36s]:  deemed too serious to be dealt with
# [681.36s - 683.36s]:  via the flag system alone and it's
# [683.36s - 685.76s]:  time to get the big guns out. Once
# [685.76s - 687.84s]:  deployed the safety car enters the
# [687.84s - 689.44s]:  circuit from the pit lane and the
# [689.44s - 691.52s]:  car in first place must then follow
# [691.52s - 693.60s]:  the safety car around at reduced
# [693.60s - 695.36s]:  speed while the rest of the pack
# [695.36s - 697.68s]:  follows behind. No overtaking is
# [697.68s - 699.04s]:  permitted under safety car
# [699.04s - 701.28s]:  conditions and drivers must drive
# [701.28s - 702.80s]:  about the same speed as the car
# [702.80s - 704.72s]:  in front. This will help make for a
# [704.72s - 706.56s]:  tight pack of cars moving around the
# [706.56s - 708.80s]:  circuit at relatively low speed
# [708.80s - 711.20s]:  while any incidents can be dealt with.
# [711.20s - 713.84s]:  Safes houses. Any driver getting too
# [713.84s - 715.76s]:  close or too far from the cars around
# [715.76s - 717.92s]:  them will be penalized. Once an
# [717.92s - 719.60s]:  incident has been cleared the race
# [719.60s - 721.28s]:  director will instruct the safety
# [721.28s - 723.20s]:  car driver on when they're expected
# [723.20s - 725.36s]:  to return to the pits. As the safety
# [725.36s - 727.12s]:  car peels away into the pit lane the
# [727.12s - 728.88s]:  car in first place dictates and
# [728.88s - 730.32s]:  controls the pace of the rest of the
# [730.32s - 732.32s]:  pack. A driver is forbidden from
# [732.32s - 734.40s]:  overtaking until their car passes the
# [734.40s - 736.64s]:  safety car line. A white line on the
# [736.64s - 738.48s]:  track that is usually placed around
# [738.48s - 739.92s]:  the beginning of the start finish
# [740.40s - 742.00s]:  making for a pretty tense and
# [742.00s - 744.24s]:  strategic restart where a race can be
# [744.24s - 747.36s]:  won and lost on the finest margins.
# [747.36s - 750.40s]:  A virtual safety car or VSC is another
# [750.40s - 752.56s]:  way the race director can neutralize a
# [752.56s - 754.56s]:  race in the event of an incident. A
# [754.56s - 757.20s]:  VSC applies to the whole circuit
# [757.20s - 759.20s]:  and limits the drivers to a set
# [759.20s - 761.68s]:  slower variable speed limit and
# [761.68s - 764.08s]:  lap time. The race director might use
# [764.08s - 766.08s]:  the VSC in situations that don't
# [766.08s - 768.32s]:  warrant a full safety car but need
# [768.32s - 770.08s]:  something more than double-waved
# [770.08s - 772.80s]:  yellow flags. The benefit of a VSC
# [772.80s - 774.88s]:  over a regular safety car is that it
# [774.88s - 777.20s]:  preserves the gaps between the cars.
# [777.20s - 779.20s]:  If a driver has a huge lead and a
# [779.20s - 781.28s]:  regular safety car is deployed that
# [781.28s - 783.04s]:  driver will lose the lead they've
# [783.04s - 784.96s]:  built up because all cars are
# [784.96s - 786.80s]:  required to line up single file
# [786.80s - 789.52s]:  behind the safety car. With a VSC
# [789.52s - 791.20s]:  all drivers are capped to the same
# [791.20s - 792.96s]:  minimum lap time but without a
# [792.96s - 795.36s]:  physical safety car on track meaning
# [795.36s - 797.52s]:  that any gaps between cars will be
# [797.52s - 800.00s]:  more or less preserved as they are.
# [800.00s - 802.08s]:  Let's summarize. We've learned about
# [802.08s - 803.60s]:  all the different flags used to send
# [803.60s - 805.12s]:  messages to drivers in the race
# [805.12s - 807.36s]:  qualifying or practice session to keep
# [807.36s - 809.28s]:  them safe and playing by the rules.
# [809.28s - 810.88s]:  When they're not enough there's the
# [810.88s - 813.20s]:  safety car and virtual safety car.
# [813.20s - 815.12s]:  These are all used in regular and
# [815.12s - 816.96s]:  shorter sprint races which have
# [816.96s - 819.04s]:  different weekend formats but both
# [819.04s - 820.88s]:  formats have a grid determined by
# [820.88s - 822.80s]:  qualifying with pole position at the
# [822.80s - 824.48s]:  front and the same race start
# [824.48s - 826.64s]:  procedure of five lights coming on then
# [826.64s - 828.80s]:  going out to signal to the drivers it's
# [828.80s - 839.76s]:  time to race. Let's go!
# An F1 Grand Prix is an absolute festival of excitement and entertainment, taking place  over three to four days with all of the warring action culminating in the race itself.  A traditional Grand Prix weekend starts much sooner than that though, with free free practice  sessions taking place over a couple of days before race day to kick things off.  These sessions give the teams and drivers the chance to learn the track, experiment  with the conditions and test the different setups and configurations they want to use  in qualifying and the race. After those practice sessions are completed, it's  time for qualifying. In essence, this is where all the drivers go out and try to  set the fastest possible lap times they can across three knockout sessions Q1, Q2  and Q3. The fastest driver to survive all knockouts starts the race from the very  front of the grid or pole position. Behind them are the other drivers ordered  from qualifying lap times set in the rest of the starting positions for the  race. The cars use a formation lap to line up in their starting or grid  positions on a start finish straight and wait for the lights to go out and the  race begins. So how is the duration of an F1 race decided? It's a case of simple  maths. A Grand Prix distance is 305 kilometers so divide that by the  length of a single lap and round it up to a whole number and hey presto  that's the number of laps for the race. The only exception is if any  stoppages in the race cause it to run over a two-hour time limit. On the final  lap, the first car to cross the finish line and take the checkered flag wins.  Championship points are awarded for all drivers in the top 10 at the end of  the race with 25 points being awarded for first place, just one single point for  10th place plus a point if they set the fastest lap of the race. Drivers  outside the top 10 don't get any points done even if they set the  fastest lap of the race. This traditional F1 race format is a little  different on sprint race weekends however. Teams only have one practice  session before the competitive weekend starts with sprint qualifying and a  shorter race called the F1 sprint with extra points up for grabs. A sprint  weekend happens a few times per season at predetermined races on the  calendar. In some ways, it's like a regular F1 Grand Prix weekend with  practice sessions to start things off and a Grand Prix race to finish. The key  difference on sprint weekends is with fewer practice sessions it makes way for  two exhilarating high tempo sessions, sprint qualifying and the sprint  itself. A short race held the following day. Sprint qualifying decides the  grid order for Saturday sprint. It's a shorter distance designed to be run  with no mandatory pit stops so more or less flat out racing. Only the top  eight finishes in a sprint get points and fewer of them but these extra  points could prove crucial in a tight championship. You might be  surprised to learn that even getting an F1 race started successfully is not at  all a straightforward process. Loads of moving parts and rolls are all  required to work in complete harmony together to put on the show that is  Formula One racing. Let's look at how it all goes down. The cars are moved  from their garages to the grid around 40 to 50 minutes before the race is  due to start. The drivers know which grid slot they need to place their  cars into to get ready for racing. The qualifying session results decide  that. Mechanics and engineers will keep the cars in the shape they need to be  into race whilst they sit on a grid. An F1 grid is also where some of the  world's biggest celebrities, actors, sports stars, musicians and special  guests can be seen amongst the drivers and cars. Once race start time  is approaching, the teams mechanics and crew return to the garage. The  cars roar into life and we begin what's called the formation. This is a  reduced speed tour around the circuit giving the drivers a chance to  check all sys ...

# %%
# Setting up the Quadrant vector and client

from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient

client = QdrantClient(":memory:")

# Create the collection before using it
if not client.collection_exists(collection_name="test"):
    client.create_collection(
        collection_name="test",
        vectors_config={"size": embeddings.embed_query("test").__len__(), "distance": "Cosine"}
    )

vector_store = QdrantVectorStore(
    client=client,
    collection_name="test",
    embedding=embeddings,
)

# %%
# Text splitter

from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100) # You can adjust this sizes as per your input.
chunks = splitter.split_text(transcript)

print(f"Split into {len(chunks)} chunks")
# Out:
# ✅ Split into 2 chunks

# %%
# Add chunks to quadrant

vector_store.add_texts(chunks) 
retriever = vector_store.as_retriever(search_kwargs={"k": 3}) # k value determines the number of chunks that will be displayed

# %% [markdown]
# ### Taking the example of two different queries to test the model accuracy based on semantic chunks and gemini llms

# %%
query1 = "What is the purpose of the practice sessions held before the main Grand Prix race?"

# Retrieve top-k similar chunks
results = vector_store.similarity_search(query1, k=3)  # It will return top three most similar docs

# Inspect results
for i, doc in enumerate(results, 1):
    print(f"\nResult {i}:")
    print(doc.metadata)
    print(doc.page_content[:500], "...")
# Out:
# Result 1:
# {'_id': '5a21a1966a934ad296ffd10cf01df93b', '_collection_name': 'test'}
# An F1 Grand Prix is an absolute festival of excitement and entertainment, taking place  over three to four days with all of the warring action culminating in the race itself.  A traditional Grand Prix weekend starts much sooner than that though, with free free practice  sessions taking place over a couple of days before race day to kick things off.  These sessions give the teams and drivers the chance to learn the track, experiment  with the conditions and test the different setups and ...
#
# Result 2:
# {'_id': '22243bc162894cf18d9a9da77868de2f', '_collection_name': 'test'}
# the chance to learn the track, experiment  with the conditions and test the different setups and configurations they want to use  in qualifying and the race. After those practice sessions are completed, it's  time for qualifying. In essence, this is where all the drivers go out and try to  set the fastest possible lap times they can across three knockout sessions Q1, Q2  and Q3. The fastest driver to survive all knockouts starts the race from the very  front of the grid or pole position. Behind ...
#
# Result 3:
# {'_id': 'c3cdde4cb76d47fb937d845727dd2559', '_collection_name': 'test'}
# sprint race weekends however. Teams only have one practice  session before the competitive weekend starts with sprint qualifying and a  shorter race called the F1 sprint with extra points up for grabs. A sprint  weekend happens a few times per season at predetermined races on the  calendar. In some ways, it's like a regular F1 Grand Prix weekend with  practice sessions to start things off and a Grand Prix race to finish. The key  difference on sprint weekends is with fewer practice sessions it ...

# %%
query2 = "How is the total number of laps in an F1 race determined?"

# Retrieve top-k similar chunks
results = vector_store.similarity_search(query2, k=3)  # It will return top three most similar docs

# Inspect results
for i, doc in enumerate(results, 1):
    print(f"\nResult {i}:")
    print(doc.page_content[:500], "...")
# Out:
# Result 1:
# of an F1 race decided? It's a case of simple  maths. A Grand Prix distance is 305 kilometers so divide that by the  length of a single lap and round it up to a whole number and hey presto  that's the number of laps for the race. The only exception is if any  stoppages in the race cause it to run over a two-hour time limit. On the final  lap, the first car to cross the finish line and take the checkered flag wins.  Championship points are awarded for all drivers in the top 10 at the end of  the ...
#
# Result 2:
# to survive all knockouts starts the race from the very  front of the grid or pole position. Behind them are the other drivers ordered  from qualifying lap times set in the rest of the starting positions for the  race. The cars use a formation lap to line up in their starting or grid  positions on a start finish straight and wait for the lights to go out and the  race begins. So how is the duration of an F1 race decided? It's a case of simple  maths. A Grand Prix distance is 305 kilometers so ...
#
# Result 3:
# flag wins.  Championship points are awarded for all drivers in the top 10 at the end of  the race with 25 points being awarded for first place, just one single point for  10th place plus a point if they set the fastest lap of the race. Drivers  outside the top 10 don't get any points done even if they set the  fastest lap of the race. This traditional F1 race format is a little  different on sprint race weekends however. Teams only have one practice  session before the competitive weekend ...

# %% [markdown]
# ### Using Gemini to answer the question based on the given context

# %%
# with query1

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite")

# Combine the context
context = "\n\n".join(doc.page_content for doc in results)

prompt = f"""You are a helpful assistant.

Based on the following context from an audio transcription, answer the user's question.

Context:
{context}

Question: {query1}
"""

response = llm.invoke([HumanMessage(content=prompt)])
print("\n Gemini Answer:\n", response.content)
# Out:
#  Gemini Answer:
#  The purpose of the practice sessions is for the teams and drivers to:
#
# *   Learn the track.
# *   Experiment with the conditions.
# *   Test different setups and configurations they want to use in qualifying and the race.

# %%
# with query 2

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite")

# Combine the context
context = "\n\n".join(doc.page_content for doc in results)

prompt = f"""You are a helpful assistant.

Based on the following context from an audio transcription, answer the user's question.

Context:
{context}

Question: {query2}
"""

response = llm.invoke([HumanMessage(content=prompt)])
print("\n Gemini Answer:\n", response.content)
# Out:
#  Gemini Answer:
#  The total number of laps in an F1 race is determined by dividing the Grand Prix distance (305 kilometers) by the length of a single lap and rounding up to a whole number. However, if the race is stopped and runs over a two-hour time limit, this can affect the number of laps.

# %% [markdown]
# ##### 🤷‍♀️Note the difference between the two , semantic search picks up the ouput from pre existing array based on similarity no makeup while gemini use some makeup and also re-structure the output to make it more readable and understandable .

# %% [markdown]
# # Similarily for the video input , we can use the following pipeline:

# %%
import subprocess
import os

def extract_audio_from_video(video_path: str, output_audio_path: str = "audio_from_video.wav"):
    if not os.path.exists(video_path):
        raise FileNotFoundError(f"Video file not found: {video_path}")
    
    command = [
        "ffmpeg",
        "-y",  # overwrite output if exists
        "-i", video_path,
        "-ac", "1",           # mono
        "-ar", "16000",       # 16 kHz
        output_audio_path
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        print("Audio extracted successfully.")
    except subprocess.CalledProcessError as e:
        print("FFmpeg error:")
        print(e.stderr)
        raise

    return output_audio_path

# %%
def video_rag_pipeline(video_path: str, query: str):
    # Step 1: Extract audio
    audio_path = extract_audio_from_video(video_path)

    # Step 2: Transcribe audio
    transcript = transcribe_audio_local(audio_path)

    # Step 3: Chunk
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    chunks = splitter.split_text(transcript)

    # Step 4: Vector store
    vector_store.add_texts(chunks)

    # Step 5: Semantic search + RAG
    retriever = vector_store.as_retriever(search_kwargs={"k": 3})
    retrieved_docs = retriever.invoke(query)
    semantic_chunks = [doc.page_content for doc in retrieved_docs]

    context = "\n\n".join(semantic_chunks)
    prompt = f"""
You are a helpful assistant. Based on the following context from a video transcription, answer the user's question.

Context:
{context}

Question:
{query}
"""
    llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite", temperature=0.3)
    gemini_response = llm.invoke(prompt).content

    return {
        "semantic_chunks": semantic_chunks,
        "gemini_answer": gemini_response
    }

# %%
query= "what does he talking about?"
result = video_rag_pipeline("video_data.mp4", query)
# Out:
# [✔] Audio extracted successfully.
# 🔍 Loading Whisper model: )
# 🎙️ Transcribing: audio_from_video.wav
# [0.00s - 18.14s]:  Wow, what an audience, but if I'm being honest, I don't care what you think of my talk.
# [18.14s - 19.14s]:  I don't.
# [19.14s - 23.28s]:  I care what the internet thinks of my talk, because they're the ones who get it seen
# [23.28s - 24.52s]:  and get it shared.
# [24.52s - 26.46s]:  And I think that's where most people get it wrong.
# [26.46s - 34.56s]:  We're talking to you here, instead of talking to you, random person, scrolling Facebook.
# [34.56s - 36.26s]:  Thanks for the click.
# [36.26s - 41.62s]:  You see, back in 2009, we all had these weird little things called attention spans.
# [41.62s - 43.38s]:  Yeah, they're gone.
# [43.38s - 44.38s]:  They're gone.
# [44.38s - 45.38s]:  We killed them.
# [45.38s - 46.38s]:  They're dead.
# [46.38s - 50.22s]:  I'm trying to think of the last time I watched an 18-minute TED Talk.
# [50.22s - 52.94s]:  It's been years, literally years.
# [52.94s - 55.70s]:  So if you're giving a TED Talk, keep it quick.
# [55.70s - 57.58s]:  I'm doing mine in under a minute.
# [57.58s - 59.22s]:  I'm at 44 seconds right now.
# [59.22s - 61.54s]:  That means we've got time for one final joke.
# [61.54s - 65.90s]:  Why are balloons so expensive?
# [65.90s - 66.90s]:  Inflation.

# %%
# Showing the output

print("Semantic Chunks:\n", "\n\n".join(result["semantic_chunks"]))
print("\nGemini Answer:\n",result["gemini_answer"])
# Out:
# Semantic Chunks:
#  Wow, what an audience, but if I'm being honest, I don't care what you think of my talk.  I don't.  I care what the internet thinks of my talk, because they're the ones who get it seen  and get it shared.  And I think that's where most people get it wrong.  We're talking to you here, instead of talking to you, random person, scrolling Facebook.  Thanks for the click.  You see, back in 2009, we all had these weird little things called attention spans.  Yeah, they're gone.  They're gone.  We killed
#
# Wow, what an audience, but if I'm being honest, I don't care what you think of my talk.  I don't.  I care what the internet thinks of my talk, because they're the ones who get it seen  and get it shared.  And I think that's where most people get it wrong.  We're talking to you here, instead of talking to you, random person, scrolling Facebook.  Thanks for the click.  You see, back in 2009, we all had these weird little things called attention spans.  Yeah, they're gone.  They're gone.  We killed
#
# Yeah, they're gone.  They're gone.  We killed them.  They're dead.  I'm trying to think of the last time I watched an 18-minute TED Talk.  It's been years, literally years.  So if you're giving a TED Talk, keep it quick.  I'm doing mine in under a minute.  I'm at 44 seconds right now.  That means we've got time for one final joke.  Why are balloons so expensive?  Inflation.
#
# Gemini Answer:
#  The speaker is talking about how to give a talk in the current internet age, focusing on the importance of capturing the attention of online viewers. He emphasizes that he cares more about what the internet thinks of his talk than the live audience, because online viewers are the ones who share and promote content. He also mentions the decline of attention spans and the need to keep talks short and engaging. Finally, he ends with a joke.

# %% [markdown]
# ## End
